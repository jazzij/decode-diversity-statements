# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from collections import Counter
nltk.download('wordnet')
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
import difflib
import pandas as pd
nltk.download('words')
from nltk.stem import LancasterStemmer
lancaster=LancasterStemmer()
import os
from nltk.tag import pos_tag
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\manalais\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\manalais\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
'''
Import the uniquewordslist.txt which will be used for the root words
'''
import nltk
import os

textdir = os.path.join(r'C:\Users\manalais\decode-diversity-statements')
filename = "uniquewordslist.txt"

text = []
with open(os.path.join(textdir, filename), 'r') as file:
        text = file.read()
print(text)
# Out:
# memory
# vandalism
# violently
# condolences
# slavery
# antiracist
# kneeling
# blacklivesmatter
# anti-racism
# inequalities
# identities
# shooting
# protesting
# inequity
# died
# violent
# struggle
# activities
# anti-racist
# minority
# loss
# force
# humanity
# killed
# grief
# inequities
# white
# voices
# pain
# systemic
# minneapolis
# discrimination
# american
# respect
# arbery
# action
# social
# lives
# racial
# color
# americans
# ahmaud
# black
# anger
# values
# inclusive
# commitment
# pandemic
# past
# taylor
# life
# breonna
# issues
# rights
# race
# right
# fear
# protests
# challenges
# deaths
# hate
# officers
# sadness
# killing
# injustices
# video
# equality
# civil
# oppression
# crisis
# killings
# policies
# protest
# victims
# inequality
# murder
# ethnicity
# skin
# government
# underrepresented
# unrest
# hurt
# frustration
# minnesota
# angry
# movement
# african-american
# privilege
# tragedies
# mourn
# murdered
# arrested
# demonstrations
# problem
# historically
# unarmed
# vulnerable
# mourning
# threat
# recently
# suffered
# advocacy
# anti-asian
# unprecedented
# success
# cases
# aware
# urgent
# represent
# pursuit
# criminal
# respectful
# unjust
# posts
# George
# Floyd

# %%
'''
TOKENIZE TEXT
'''
from nltk.tokenize import word_tokenize

tokenizer = nltk.RegexpTokenizer(r"\w+") #regex to get all words, including numbers, but not punctuaction
tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['memory', 'vandalism', 'violently', 'condolences', 'slavery', 'antiracist', 'kneeling', 'blacklivesmatter', 'anti', 'racism', 'inequalities', 'identities', 'shooting', 'protesting', 'inequity', 'died', 'violent', 'struggle', 'activities', 'anti', 'racist', 'minority', 'loss', 'force', 'humanity', 'killed', 'grief', 'inequities', 'white', 'voices', 'pain', 'systemic', 'minneapolis', 'discrimination', 'american', 'respect', 'arbery', 'action', 'social', 'lives', 'racial', 'color', 'americans', 'ahmaud', 'black', 'anger', 'values', 'inclusive', 'commitment', 'pandemic', 'past', 'taylor', 'life', 'breonna', 'issues', 'rights', 'race', 'right', 'fear', 'protests', 'challenges', 'deaths', 'hate', 'officers', 'sadness', 'killing', 'injustices', 'video', 'equality', 'civil', 'oppression', 'crisis', 'killings', 'policies', 'protest', 'victims', 'inequality', 'murder', 'ethnicity', 'skin', 'government', 'underrepresented', 'unrest', 'hurt', 'frustration', 'minnesota', 'angry', 'movement', 'african', 'american', 'privilege', 'tragedies', 'mourn', 'murdered', 'arrested', 'demonstrations', 'problem', 'historically', 'unarmed', 'vulnerable', 'mourning', 'threat', 'recently', 'suffered', 'advocacy', 'anti', 'asian', 'unprecedented', 'success', 'cases', 'aware', 'urgent', 'represent', 'pursuit', 'criminal', 'respectful', 'unjust', 'posts', 'George', 'Floyd']

# %%
'''
Remove punctuation
'''

punctuations="\"!#â$%&'()*+,-./:;<=>?@[\]^_`{|}~–"
for word in tokens:
    if word in punctuations:
        tokens.remove(word)
tokens
# Out:
# ['memory',
#  'vandalism',
#  'violently',
#  'condolences',
#  'slavery',
#  'antiracist',
#  'kneeling',
#  'blacklivesmatter',
#  'anti',
#  'racism',
#  'inequalities',
#  'identities',
#  'shooting',
#  'protesting',
#  'inequity',
#  'died',
#  'violent',
#  'struggle',
#  'activities',
#  'anti',
#  'racist',
#  'minority',
#  'loss',
#  'force',
#  'humanity',
#  'killed',
#  'grief',
#  'inequities',
#  'white',
#  'voices',
#  'pain',
#  'systemic',
#  'minneapolis',
#  'discrimination',
#  'american',
#  'respect',
#  'arbery',
#  'action',
#  'social',
#  'lives',
#  'racial',
#  'color',
#  'americans',
#  'ahmaud',
#  'black',
#  'anger',
#  'values',
#  'inclusive',
#  'commitment',
#  'pandemic',
#  'past',
#  'taylor',
#  'life',
#  'breonna',
#  'issues',
#  'rights',
#  'race',
#  'right',
#  'fear',
#  'protests',
#  'challenges',
#  'deaths',
#  'hate',
#  'officers',
#  'sadness',
#  'killing',
#  'injustices',
#  'video',
#  'equality',
#  'civil',
#  'oppression',
#  'crisis',
#  'killings',
#  'policies',
#  'protest',
#  'victims',
#  'inequality',
#  'murder',
#  'ethnicity',
#  'skin',
#  'government',
#  'underrepresented',
#  'unrest',
#  'hurt',
#  'frustration',
#  'minnesota',
#  'angry',
#  'movement',
#  'african',
#  'american',
#  'privilege',
#  'tragedies',
#  'mourn',
#  'murdered',
#  'arrested',
#  'demonstrations',
#  'problem',
#  'historically',
#  'unarmed',
#  'vulnerable',
#  'mourning',
#  'threat',
#  'recently',
#  'suffered',
#  'advocacy',
#  'anti',
#  'asian',
#  'unprecedented',
#  'success',
#  'cases',
#  'aware',
#  'urgent',
#  'represent',
#  'pursuit',
#  'criminal',
#  'respectful',
#  'unjust',
#  'posts',
#  'George',
#  'Floyd']

# %%
'''tag part of speech first. result is list of (word, tag)'''
tagged_tokens = nltk.pos_tag(tokens)
print(tagged_tokens)
# Out:
# [('memory', 'NN'), ('vandalism', 'NN'), ('violently', 'RB'), ('condolences', 'VBZ'), ('slavery', 'JJ'), ('antiracist', 'NN'), ('kneeling', 'VBG'), ('blacklivesmatter', 'NN'), ('anti', 'JJ'), ('racism', 'NN'), ('inequalities', 'NNS'), ('identities', 'VBZ'), ('shooting', 'VBG'), ('protesting', 'VBG'), ('inequity', 'NN'), ('died', 'VBD'), ('violent', 'JJ'), ('struggle', 'NN'), ('activities', 'NNS'), ('anti', 'VBP'), ('racist', 'JJ'), ('minority', 'NN'), ('loss', 'NN'), ('force', 'NN'), ('humanity', 'NN'), ('killed', 'VBN'), ('grief', 'JJ'), ('inequities', 'NNS'), ('white', 'JJ'), ('voices', 'NNS'), ('pain', 'VBP'), ('systemic', 'JJ'), ('minneapolis', 'NN'), ('discrimination', 'NN'), ('american', 'JJ'), ('respect', 'NN'), ('arbery', 'DT'), ('action', 'NN'), ('social', 'JJ'), ('lives', 'VBZ'), ('racial', 'JJ'), ('color', 'NN'), ('americans', 'VBZ'), ('ahmaud', 'JJ'), ('black', 'JJ'), ('anger', 'NN'), ('values', 'NNS'), ('inclusive', 'JJ'), ('commitment', 'NN'), ('pandemic', 'JJ'), ('past', 'NN'), ('taylor', 'NN'), ('life', 'NN'), ('breonna', 'NN'), ('issues', 'NNS'), ('rights', 'NNS'), ('race', 'NN'), ('right', 'JJ'), ('fear', 'NN'), ('protests', 'NNS'), ('challenges', 'VBZ'), ('deaths', 'NNS'), ('hate', 'NN'), ('officers', 'NNS'), ('sadness', 'VBP'), ('killing', 'VBG'), ('injustices', 'NNS'), ('video', 'JJ'), ('equality', 'NN'), ('civil', 'JJ'), ('oppression', 'NN'), ('crisis', 'NN'), ('killings', 'NNS'), ('policies', 'NNS'), ('protest', 'VBP'), ('victims', 'NNS'), ('inequality', 'NN'), ('murder', 'NN'), ('ethnicity', 'NN'), ('skin', 'JJ'), ('government', 'NN'), ('underrepresented', 'VBD'), ('unrest', 'JJ'), ('hurt', 'NN'), ('frustration', 'NN'), ('minnesota', 'NN'), ('angry', 'JJ'), ('movement', 'NN'), ('african', 'JJ'), ('american', 'JJ'), ('privilege', 'NN'), ('tragedies', 'NNS'), ('mourn', 'VBP'), ('murdered', 'VBN'), ('arrested', 'JJ'), ('demonstrations', 'NNS'), ('problem', 'NN'), ('historically', 'RB'), ('unarmed', 'VBD'), ('vulnerable', 'JJ'), ('mourning', 'NN'), ('threat', 'NN'), ('recently', 'RB'), ('suffered', 'VBD'), ('advocacy', 'NN'), ('anti', 'JJ'), ('asian', 'JJ'), ('unprecedented', 'JJ'), ('success', 'NN'), ('cases', 'NNS'), ('aware', 'JJ'), ('urgent', 'JJ'), ('represent', 'NN'), ('pursuit', 'NN'), ('criminal', 'JJ'), ('respectful', 'NN'), ('unjust', 'JJ'), ('posts', 'NNS'), ('George', 'NNP'), ('Floyd', 'NNP')]

# %%
'''
Stemming and Lemmatization
'''
lemmatizer = WordNetLemmatizer()
clean_words = []

for words, tag in tagged_tokens:
    if  not tag.startswith('NNP' or 'NNPS'): # remove propr nouns
        if tag.startswith('NN' or 'NNS'):
            clean_words.append(lemmatizer.lemmatize(words, pos='n'))
        elif tag.startswith('NNP' or 'NNPS'):
            clean_words.append(wordnet_lemmatizer.lemmatize(word, pos='n'))
        elif tag.startswith('VB' or 'VBP' or 'VBD' or 'VBG' or 'VBP' or 'VBZ'):
            clean_words.append(lemmatizer.lemmatize(words, pos='v'))
        elif tag.startswith('JJ' or 'JJR' or 'JJS' ):
            clean_words.append(lemmatizer.lemmatize(words, pos='a'))
        elif tag.startswith('RB' or 'RBR' or 'RBS' or 'RP'):
            clean_words.append(lemmatizer.lemmatize(words, pos='r'))
        else:
            clean_words.append(lemmatizer.lemmatize(words))

print(clean_words)
# Out:
# ['memory', 'vandalism', 'violently', 'condolences', 'slavery', 'antiracist', 'kneel', 'blacklivesmatter', 'anti', 'racism', 'inequality', 'identities', 'shoot', 'protest', 'inequity', 'die', 'violent', 'struggle', 'activity', 'anti', 'racist', 'minority', 'loss', 'force', 'humanity', 'kill', 'grief', 'inequity', 'white', 'voice', 'pain', 'systemic', 'minneapolis', 'discrimination', 'american', 'respect', 'arbery', 'action', 'social', 'live', 'racial', 'color', 'americans', 'ahmaud', 'black', 'anger', 'value', 'inclusive', 'commitment', 'pandemic', 'past', 'taylor', 'life', 'breonna', 'issue', 'right', 'race', 'right', 'fear', 'protest', 'challenge', 'death', 'hate', 'officer', 'sadness', 'kill', 'injustice', 'video', 'equality', 'civil', 'oppression', 'crisis', 'killing', 'policy', 'protest', 'victim', 'inequality', 'murder', 'ethnicity', 'skin', 'government', 'underrepresented', 'unrest', 'hurt', 'frustration', 'minnesota', 'angry', 'movement', 'african', 'american', 'privilege', 'tragedy', 'mourn', 'murder', 'arrested', 'demonstration', 'problem', 'historically', 'unarm', 'vulnerable', 'mourning', 'threat', 'recently', 'suffer', 'advocacy', 'anti', 'asian', 'unprecedented', 'success', 'case', 'aware', 'urgent', 'represent', 'pursuit', 'criminal', 'respectful', 'unjust', 'post']

# %%
''' Remove all the stop words'''
for word in clean_words:
    if word in stopwords.words('english'):
        clean_words.remove(word)
    if word == 'ahmaud' or word =='taylor' or word =='breonna' or word =='anti' or word =='arbery': # This part is manual work because the POS did not tag these names as NNP and so did not remove it
        clean_words.remove(word)     
print(clean_words)
# Out:
# ['memory', 'vandalism', 'violently', 'condolences', 'slavery', 'antiracist', 'kneel', 'blacklivesmatter', 'racism', 'inequality', 'identities', 'shoot', 'protest', 'inequity', 'die', 'violent', 'struggle', 'activity', 'racist', 'minority', 'loss', 'force', 'humanity', 'kill', 'grief', 'inequity', 'white', 'voice', 'pain', 'systemic', 'minneapolis', 'discrimination', 'american', 'respect', 'action', 'social', 'live', 'racial', 'color', 'americans', 'black', 'anger', 'value', 'inclusive', 'commitment', 'pandemic', 'past', 'life', 'issue', 'right', 'race', 'right', 'fear', 'protest', 'challenge', 'death', 'hate', 'officer', 'sadness', 'kill', 'injustice', 'video', 'equality', 'civil', 'oppression', 'crisis', 'killing', 'policy', 'protest', 'victim', 'inequality', 'murder', 'ethnicity', 'skin', 'government', 'underrepresented', 'unrest', 'hurt', 'frustration', 'minnesota', 'angry', 'movement', 'african', 'american', 'privilege', 'tragedy', 'mourn', 'murder', 'arrested', 'demonstration', 'problem', 'historically', 'unarm', 'vulnerable', 'mourning', 'threat', 'recently', 'suffer', 'advocacy', 'asian', 'unprecedented', 'success', 'case', 'aware', 'urgent', 'represent', 'pursuit', 'criminal', 'respectful', 'unjust', 'post']

# %%
'''(Manual work): The list of words is not complete sentence therefore,
lemmatization function POS does not tag the following correctly.
'''
for words in clean_words:
    if words == "racism":
        clean_words[clean_words.index("racism")] = "race"   
    if words == 'violently':
        clean_words[clean_words.index('violently')] = 'violent'
    if words == 'identities':
        clean_words[clean_words.index('identities')] = 'identity'
    if words == 'systemic':
        clean_words[clean_words.index('systemic')] = 'system'
    if words == 'racial':
        clean_words[clean_words.index('racial')] = 'race'
    if words == 'killing':
        clean_words[clean_words.index('killing')] = 'kill'
    if words =='underrepresented':
        clean_words[clean_words.index('underrepresented')]  = 'underrepresent'
    if words =='americans':
        clean_words[clean_words.index('americans')]  = 'american'
    if words =='arrested':
        clean_words[clean_words.index('arrested')]  = 'arrest' 
    if words =='mourning':
        clean_words[clean_words.index('mourning')]  = 'mourn'
    if words =='racist':
        clean_words[clean_words.index('racist')]  = 'race'
clean_words
# Out:
# ['memory',
#  'vandalism',
#  'violent',
#  'condolences',
#  'slavery',
#  'antiracist',
#  'kneel',
#  'blacklivesmatter',
#  'race',
#  'inequality',
#  'identity',
#  'shoot',
#  'protest',
#  'inequity',
#  'die',
#  'violent',
#  'struggle',
#  'activity',
#  'race',
#  'minority',
#  'loss',
#  'force',
#  'humanity',
#  'kill',
#  'grief',
#  'inequity',
#  'white',
#  'voice',
#  'pain',
#  'system',
#  'minneapolis',
#  'discrimination',
#  'american',
#  'respect',
#  'action',
#  'social',
#  'live',
#  'race',
#  'color',
#  'american',
#  'black',
#  'anger',
#  'value',
#  'inclusive',
#  'commitment',
#  'pandemic',
#  'past',
#  'life',
#  'issue',
#  'right',
#  'race',
#  'right',
#  'fear',
#  'protest',
#  'challenge',
#  'death',
#  'hate',
#  'officer',
#  'sadness',
#  'kill',
#  'injustice',
#  'video',
#  'equality',
#  'civil',
#  'oppression',
#  'crisis',
#  'kill',
#  'policy',
#  'protest',
#  'victim',
#  'inequality',
#  'murder',
#  'ethnicity',
#  'skin',
#  'government',
#  'underrepresent',
#  'unrest',
#  'hurt',
#  'frustration',
#  'minnesota',
#  'angry',
#  'movement',
#  'african',
#  'american',
#  'privilege',
#  'tragedy',
#  'mourn',
#  'murder',
#  'arrest',
#  'demonstration',
#  'problem',
#  'historically',
#  'unarm',
#  'vulnerable',
#  'mourn',
#  'threat',
#  'recently',
#  'suffer',
#  'advocacy',
#  'asian',
#  'unprecedented',
#  'success',
#  'case',
#  'aware',
#  'urgent',
#  'represent',
#  'pursuit',
#  'criminal',
#  'respectful',
#  'unjust',
#  'post']

# %%
'''Remove duplicate words'''
clean_words = list(set(clean_words))  # removes the duplicate words
print(clean_words)
# Out:
# ['minnesota', 'race', 'pursuit', 'color', 'underrepresent', 'equality', 'slavery', 'system', 'criminal', 'represent', 'video', 'arrest', 'victim', 'inequity', 'kneel', 'inclusive', 'unarm', 'recently', 'live', 'frustration', 'inequality', 'condolences', 'advocacy', 'die', 'blacklivesmatter', 'unrest', 'skin', 'suffer', 'hurt', 'problem', 'black', 'unprecedented', 'civil', 'grief', 'respect', 'struggle', 'identity', 'life', 'tragedy', 'privilege', 'post', 'action', 'social', 'death', 'antiracist', 'hate', 'protest', 'commitment', 'past', 'anger', 'violent', 'shoot', 'government', 'activity', 'value', 'historically', 'officer', 'injustice', 'right', 'sadness', 'case', 'demonstration', 'respectful', 'loss', 'discrimination', 'minority', 'fear', 'force', 'asian', 'policy', 'urgent', 'voice', 'american', 'african', 'issue', 'murder', 'angry', 'challenge', 'aware', 'vulnerable', 'threat', 'minneapolis', 'kill', 'crisis', 'vandalism', 'memory', 'ethnicity', 'mourn', 'humanity', 'unjust', 'oppression', 'success', 'pandemic', 'pain', 'white', 'movement']

# %%
'''Create an empty dictionary with all the root words as its keys'''
dic = {}
for root in clean_words:
    dic[root] = []

# %%
'''
Import all of the statements from the tokenText folder and extract the derivatives of root words
'''

#The Function stop_words was written by Kumbula
filtered_words = []
def stop_words(tokens):
    """
    This function is for removing the stopwords from the text file.
    Filename: Name of the file
    return: filtered_words
    """

    stop_words = set(stopwords.words('english'))  # Creating a List of stopwords
    for w in tokens:
        if w not in stop_words:
            filtered_words.append(w)  # Add all words after stopwords have been removed
    # print ("Filtered_words:",filtered_words )
    return filtered_words


# Go through each statement and find words that are derivatives of root words
current_dir = os.getcwd()
textdir = (r"C:\Users\manalais\decode-diversity-statements\tokenText")
for filename in os.listdir(textdir)[:]:
    filepath = os.path.join(textdir, filename)
    with open(filepath, "r") as file:
        text = file.read()
        tokens = tokenizer.tokenize(text)  # Returns a text as a list of words with punctuations
        tokens = [token.lower() for token in tokens if token.isalpha()]  # Changes all the words into lower case        
        for root in clean_words:
            for leaf in tokens:
                similiarity = difflib.SequenceMatcher(None, root, leaf).ratio()
                if similiarity > 0.85:
                    
                    if leaf not in dic[root]:   #only append to dictionary if the value doesn't already exist
                        dic[root].append(leaf)

        
    
    
print(dic)
# Out:
# {'minnesota': ['minnesota'], 'race': ['race', 'races', 'grace'], 'pursuit': ['pursuit'], 'color': ['color', 'colour'], 'underrepresent': ['underrepresented'], 'equality': ['equality', 'quality', 'equity', 'inequality'], 'slavery': ['slavery'], 'system': ['systems', 'system', 'systemic'], 'criminal': ['criminal', 'criminals'], 'represent': ['represents', 'represent', 'present', 'representing', 'represented'], 'video': ['video', 'videos'], 'arrest': ['arrest', 'arrested'], 'victim': ['victims', 'victim'], 'inequity': ['inequity', 'equity', 'inequality'], 'kneel': ['kneel', 'kneels', 'knee'], 'inclusive': ['inclusive', 'inclusivevt'], 'unarm': [], 'recently': ['recently', 'recent'], 'live': ['live', 'lived', 'lives', 'alive'], 'frustration': ['frustration', 'frustrations'], 'inequality': ['inequality', 'equality', 'inequity'], 'condolences': ['condolences'], 'advocacy': ['advocacy'], 'die': ['die', 'died', 'dies'], 'blacklivesmatter': ['blacklivesmatter'], 'unrest': ['unrest'], 'skin': ['skin', 'sin'], 'suffer': ['suffer', 'suffered'], 'hurt': ['hurt', 'hurts'], 'problem': ['problems', 'problem'], 'black': ['black', 'blacks', 'lack', 'back'], 'unprecedented': ['unprecedented'], 'civil': ['civil'], 'grief': ['grief'], 'respect': ['respect', 'respects', 'respected'], 'struggle': ['struggle', 'struggles', 'struggled'], 'identity': ['identity', 'identify'], 'life': ['life'], 'tragedy': ['tragedy'], 'privilege': ['privileged', 'privilege', 'privileges'], 'post': ['post', 'posts', 'posit'], 'action': ['action', 'actions', 'reaction', 'inaction', 'fraction'], 'social': ['social', 'socially', 'societal'], 'death': ['death', 'deaths'], 'antiracist': ['antiracist', 'antiracism'], 'hate': ['hate'], 'protest': ['protests', 'protest', 'protect', 'protested'], 'commitment': ['commitment', 'commitments', 'recommitment'], 'past': ['past', 'pat'], 'anger': ['anger', 'danger'], 'violent': ['violent', 'violently'], 'shoot': ['shot'], 'government': ['government'], 'activity': ['activity'], 'value': ['values', 'value', 'valued'], 'historically': ['historical', 'historically'], 'officer': ['officer', 'officers', 'office', 'offices'], 'injustice': ['injustice', 'injustices', 'justice'], 'right': ['rights', 'right', 'bright', 'wright'], 'sadness': ['sadness'], 'case': ['case', 'chase', 'cease', 'cause', 'cases'], 'demonstration': ['demonstrations', 'demonstration', 'demonstrating'], 'respectful': ['respectful', 'respectfully'], 'loss': ['loss', 'los'], 'discrimination': ['discrimination', 'nondiscrimination', 'discriminatory'], 'minority': ['minority'], 'fear': ['fear', 'far', 'ear', 'fears'], 'force': ['force', 'forces', 'forced', 'fore'], 'asian': ['asian'], 'policy': ['policy'], 'urgent': ['urgent', 'urgently'], 'voice': ['voices', 'voice', 'vice'], 'american': ['americans', 'america', 'american'], 'african': ['african'], 'issue': ['issues', 'issued', 'issue'], 'murder': ['murder', 'murders', 'murdered'], 'angry': ['angry'], 'challenge': ['challenges', 'challenge', 'challenged'], 'aware': ['aware'], 'vulnerable': ['vulnerable'], 'threat': ['threat', 'treat', 'threats', 'threaten'], 'minneapolis': ['minneapolis'], 'kill': ['kill'], 'crisis': ['crisis'], 'vandalism': ['vandalism', 'vandals'], 'memory': ['memory', 'emory'], 'ethnicity': ['ethnicity'], 'mourn': ['mourn', 'mourns'], 'humanity': ['humanity'], 'unjust': ['unjust', 'unjustly'], 'oppression': ['oppression'], 'success': ['success', 'successes'], 'pandemic': ['pandemic', 'pandemics'], 'pain': ['pain', 'paint', 'pains'], 'white': ['white'], 'movement': ['movement', 'moment']}

# %%
import json  
          
with open("sample.json", "w") as outfile:  
    json.dump(dic, outfile)

# %%
'''(Manual work): The difflib.SequenceMatcher matches some words that are similiar but not leaves of the root word.
For instance, pain --> paint. Therefore, I am removing them from the dictionary values manually '''

# for value in dic.values():
#     for i in value:
#         if i == 'paint':
#             value.remove(i)
#         if i == 'posit':
#             value.remove(i)
#         if i == 'present':
#             value.remove(i)
#         if i == 'los':
#             value.remove(i)
#         if i == 'pat':
#             value.remove(i)
#         if i == 'sin':
#             value.remove(i)
#         if i == 'lack':
#             value.remove(i)
#         if i == 'back':
#             value.remove(i)
#         if i == 'far':
#             value.remove(i)
#         if i == 'ears':
#             value.remove(i)
#         if i == 'inclusivevt':
#             value.remove(i)
#         if i == 'fraction':
#             value.remove(i)
#         if i == 'reaction':
#             value.remove(i)
#         if i == 'emory':
#             value.remove(i)
#         if i == 'fore':
#             value.remove(i) 
#         if i == 'bright':
#             value.remove(i)
#         if i == 'wright':
#             value.remove(i)
#         if i == 'identify':
#             value.remove(i)
#         if i == 'grace':
#             value.remove(i)
#         if i == 'chase':
#             value.remove(i)
#         if i == 'ceases':
#             value.remove(i)
#         if i == 'causes':
#             value.remove(i) 
#         if i == 'vice':
#             value.remove(i)
#         if i == 'danger':
#             value.remove(i)
#         if i == 'treat':
#             value.remove(i)
#         if i == 'quality':
#             value.remove(i)
#         if i == 'ear':
#             value.remove(i)
#         if i == 'cease':
#             value.remove(i)
#         if i == 'cause':
#             value.remove(i)
#         if i == 'movement':
#             value.remove(i)
#         if i == 'protest':
#             value.remove(i)
#         if i == 'justice':
#             value.remove(i)
#         if i == 'nondiscrimination':
#             value.remove(i)
#         if i == 'america':
#             value.remove(i)
#         if i == 'inaction':
#             value.remove(i)
#         if i == 'knee':
#             value.remove(i)

# %%
''' (Manual work): The dictionary contains key:value errors that needs to be fixed'''
# dic['equality'] = [ 'equality']
# dic['equality']
# dic['inequity'] = ['inequity']
# dic['inequity']
# dic['officer'] = ['officer', 'officers']
# dic['officer']
# dic['race'] = ['race', 'races', 'racism', 'racist']
# dic['race']

# %%
'''Visualize the data'''

key_list = []
value_list = []


for k in dic.keys():
    key_list.append(k)
for v in dic.values():
    value_list.append(v)

print("\n" + "\033[1m" + "Root and Leaf Plot".center(60) + "\n")
for key,value in zip(key_list,value_list):
    print("\033[1m" + key + "\033[0m" + '| ' + " ".join(value))
# Out:
#                      Root and Leaf Plot
#
# minnesota| minnesota
# race| race races grace
# pursuit| pursuit
# color| color colour
# underrepresent| underrepresented
# equality| equality quality equity inequality
# slavery| slavery
# system| systems system systemic
# criminal| criminal criminals
# represent| represents represent present representing represented
# video| video videos
# arrest| arrest arrested
# victim| victims victim
# inequity| inequity equity inequality
# kneel| kneel kneels knee
# inclusive| inclusive inclusivevt
# unarm|
# recently| recently recent
# live| live lived lives alive
# frustration| frustration frustrations
# inequality| inequality equality inequity
# condolences| condolences
# advocacy| advocacy
# die| die died dies
# blacklivesmatter| blacklivesmatter
# unrest| unrest
# skin| skin sin
# suffer| suffer suffered
# hurt| hurt hurts
# problem| problems problem
# black| black blacks lack back
# unprecedented| unprecedented
# civil| civil
# grief| grief
# respect| respect respects respected
# struggle| struggle struggles struggled
# identity| identity identify
# life| life
# tragedy| tragedy
# privilege| privileged privilege privileges
# post| post posts posit
# action| action actions reaction inaction fraction
# social| social socially societal
# death| death deaths
# antiracist| antiracist antiracism
# hate| hate
# protest| protests protest protect protested
# commitment| commitment commitments recommitment
# past| past pat
# anger| anger danger
# violent| violent violently
# shoot| shot
# government| government
# activity| activity
# value| values value valued
# historically| historical historically
# officer| officer officers office offices
# injustice| injustice injustices justice
# right| rights right bright wright
# sadness| sadness
# case| case chase cease cause cases
# demonstration| demonstrations demonstration demonstrating
# respectful| respectful respectfully
# loss| loss los
# discrimination| discrimination nondiscrimination discriminatory
# minority| minority
# fear| fear far ear fears
# force| force forces forced fore
# asian| asian
# policy| policy
# urgent| urgent urgently
# voice| voices voice vice
# american| americans america american
# african| african
# issue| issues issued issue
# murder| murder murders murdered
# angry| angry
# challenge| challenges challenge challenged
# aware| aware
# vulnerable| vulnerable
# threat| threat treat threats threaten
# minneapolis| minneapolis
# kill| kill
# crisis| crisis
# vandalism| vandalism vandals
# memory| memory emory
# ethnicity| ethnicity
# mourn| mourn mourns
# humanity| humanity
# unjust| unjust unjustly
# oppression| oppression
# success| success successes
# pandemic| pandemic pandemics
# pain| pain paint pains
# white| white
# movement| movement moment
